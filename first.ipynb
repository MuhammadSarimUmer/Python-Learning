# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadSarimUmer/Python-Learning/blob/master/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world',2+2)
# Out:
# Hello world 4

# %%
number = 12
print(type(number))
# Out:
# <class 'int'>

# %% [markdown]
# # LISTS

# %%
fruits = ['apple','banana',12]
print(fruits[2])
# Out:
# 12

# %%
fruits.append('orange')
print(fruits)
# Out:
# ['apple', 'banana', 12, 'orange']

# %%
fruits.insert(1,'grapes')
print(fruits)
# Out:
# ['apple', 'grapes', 'banana', 12, 'orange']

# %%
fruits.pop()
print(fruits)
# Out:
# ['apple', 'grapes', 'banana', 12]

# %%
fruits.remove(12)

# %%
print(fruits)
fruits.sort()
print(fruits)
# Out:
# ['apple', 'grapes', 'banana']
# ['apple', 'banana', 'grapes']

# %%
for fruit in fruits:
 print(fruit)
# Out:
# apple
# banana
# grapes

# %%
colours = ('red','blue','green')
print(colours)
# Out:
# ('red', 'blue', 'green')

# %%
colours.count("red")
# Out:
# 1

# %%
student = {
    "name" : "Sarim",
    "age" : "19",
    "course" : "Linear Algebra"
}

print(student)
print(student['age'])
# Out:
# {'name': 'Sarim', 'age': '19', 'course': 'Linear Algebra'}
# 19
